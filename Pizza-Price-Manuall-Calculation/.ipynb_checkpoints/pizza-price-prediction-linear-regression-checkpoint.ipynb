# %% [markdown]
# # Pizza Price Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
pizza_data = pd.read_csv('pizza_data.csv')

# %%
pizza_data.head(10)
# Out:
#           Company          Pizza Name           Type           Size   Price
# 0  Domino's Pizza         Hand Tossed  Cheeses Pizza    Small (10")   $5.99
# 1  Domino's Pizza         Hand Tossed  Cheeses Pizza   Medium (12")   $7.99
# 2  Domino's Pizza         Hand Tossed  Cheeses Pizza    Large (14")   $9.99
# 3  Domino's Pizza        Handmade Pan  Cheeses Pizza   Medium (12")   $7.99
# 4  Domino's Pizza  Crunchy Thin Crust  Cheeses Pizza    Small (10")   $5.99
# 5  Domino's Pizza  Crunchy Thin Crust  Cheeses Pizza   Medium (12")   $7.99
# 6  Domino's Pizza  Crunchy Thin Crust  Cheeses Pizza    Large (14")   $9.99
# 7  Domino's Pizza      Brooklyn Style  Cheeses Pizza    Large (14")   $9.99
# 8  Domino's Pizza      Brooklyn Style  Cheeses Pizza  X-Large (16")  $11.99
# 9  Domino's Pizza   Gluten Free Crust  Cheeses Pizza    Small (10")   $8.99

# %%
size_inch = {'Personal':'8', 'Mini':'9', 'Small':'10', 'Medium':'12', 'Large':'14', 'X-Large':'16', 'Jumbo':'18', 'Small (10")':'10', 'Medium (12")':'12', 'Large (14")':'14', 'X-Large (16")':'16', 'X Large (16")':'16'}

# %%
pizza_data['Size'] = pizza_data['Size'].map(size_inch)

# %%
pizza_data.head(100)
# Out:
#            Company                              Pizza Name  \
# 0   Domino's Pizza                             Hand Tossed
# 1   Domino's Pizza                             Hand Tossed
# 2   Domino's Pizza                             Hand Tossed
# 3   Domino's Pizza                            Handmade Pan
# 4   Domino's Pizza                      Crunchy Thin Crust
# ..             ...                                     ...
# 95       Pizza Hut                           Stuffed Crust
# 96       Pizza Hut                            Skinny Slice
# 97       Pizza Hut  Pepperoni Lover's® Pizza (Hand-Tossed)
# 98       Pizza Hut  Pepperoni Lover's® Pizza (Hand-Tossed)
# 99       Pizza Hut    Pepperoni Lover's® Pizza (Pan Pizza)
#
#                      Type Size   Price
# 0           Cheeses Pizza   10   $5.99
# 1           Cheeses Pizza   12   $7.99
# 2           Cheeses Pizza   14   $9.99
# 3           Cheeses Pizza   12   $7.99
# 4           Cheeses Pizza   10   $5.99
# ..                    ...  ...     ...
# 95           Cheese Pizza   14  $12.49
# 96           Cheese Pizza   14  $10.49
# 97  Classic Recipe Pizzas   12  $12.49
# 98  Classic Recipe Pizzas   14  $15.49
# 99  Classic Recipe Pizzas    8   $4.79
#
# [100 rows x 5 columns]

# %%
isDominos = pizza_data['Company'] == "Domino's Pizza"
isCheeses = pizza_data['Type'] == "Cheeses Pizza"
dominos = pizza_data.loc[isDominos & isCheeses, ['Size', 'Price']]

# %%
print(dominos)
# Out:
#   Size   Price
# 0   10   $5.99
# 1   12   $7.99
# 2   14   $9.99
# 3   12   $7.99
# 4   10   $5.99
# 5   12   $7.99
# 6   14   $9.99
# 7   14   $9.99
# 8   16  $11.99
# 9   10   $8.99

# %%
dominos['Price'] = dominos['Price'].str[1:]

# %%
dominos
# Out:
#   Size  Price
# 0   10   5.99
# 1   12   7.99
# 2   14   9.99
# 3   12   7.99
# 4   10   5.99
# 5   12   7.99
# 6   14   9.99
# 7   14   9.99
# 8   16  11.99
# 9   10   8.99

# %%
dominos.drop_duplicates(subset=['Size'], inplace = True)
dominos
# Out:
#   Size  Price
# 0   10   5.99
# 1   12   7.99
# 2   14   9.99
# 8   16  11.99

# %%
new_size_with_price = pd.DataFrame({
    'Size': ['18', '20', '22'],
    'Price': ['13.99', '15.99', '17.99']
})
dominos = pd.concat([dominos, new_size_with_price], ignore_index=True)

# %%
dominos.rename(columns={'Size':'X', 'Price':'Y'}, inplace = True)
dominos
# Out:
#     X      Y
# 0  10   5.99
# 1  12   7.99
# 2  14   9.99
# 3  16  11.99
# 4  18  13.99
# 5  20  15.99
# 6  22  17.99

# %%
dominos['X'] = dominos['X'].astype(int)
dominos['Y'] = dominos['Y'].astype(float)

# %%
dominos
# Out:
#     X      Y
# 0  10   5.99
# 1  12   7.99
# 2  14   9.99
# 3  16  11.99
# 4  18  13.99
# 5  20  15.99
# 6  22  17.99

# %%
dominos.to_csv("table.csv")

# %%
xAvg = sum(dominos['X']) / len(dominos)
print(xAvg)
# Out:
# 16.0

# %%
yAvg = sum(dominos['Y']) / len(dominos)
print(yAvg)
# Out:
# 11.99

# %%
xyAvg = sum(dominos['X'] * dominos['Y']) / len(dominos)
print(xyAvg)
# Out:
# 207.84

# %%
xSqAvg = sum(dominos['X'] * dominos['X']) / len(dominos)
print(xSqAvg)
# Out:
# 272.0

# %%
m = ((xAvg * yAvg) - xyAvg) / ((xAvg * xAvg) - xSqAvg)
print(m)
# Out:
# 1.0

# %%
c = yAvg - (m * xAvg)
print(c)
# Out:
# -4.01

# %%
dominos['XY'] = dominos['X'] * dominos['Y']
dominos['XX'] = dominos['X'] * dominos['X']

# %%
dominos
# Out:
#     X      Y      XY   XX
# 0  10   5.99   59.90  100
# 1  12   7.99   95.88  144
# 2  14   9.99  139.86  196
# 3  16  11.99  191.84  256
# 4  18  13.99  251.82  324
# 5  20  15.99  319.80  400
# 6  22  17.99  395.78  484

# %%
np_array = dominos[['X', 'Y', 'XY']].to_numpy()

# %%
np_array
# Out:
# array([[ 10.  ,   5.99,  59.9 ],
#        [ 12.  ,   7.99,  95.88],
#        [ 14.  ,   9.99, 139.86],
#        [ 16.  ,  11.99, 191.84],
#        [ 18.  ,  13.99, 251.82],
#        [ 20.  ,  15.99, 319.8 ],
#        [ 22.  ,  17.99, 395.78]])

# %%
def f(x, m, c):
    return (m * x) + c

# %%
for a in np_array:
    a[2] = f(a[0], m, c)

# %%
print(np_array)
# Out:
# [[10.    5.99  5.99]
#  [12.    7.99  7.99]
#  [14.    9.99  9.99]
#  [16.   11.99 11.99]
#  [18.   13.99 13.99]
#  [20.   15.99 15.99]
#  [22.   17.99 17.99]]

# %%
plt.xlabel('Size')
plt.ylabel('Price')
plt.title('Pizza Price according to size')
for i in range(len(np_array)):
    plt.scatter(np_array[i][0], np_array[i][1])

# %%
numerator = 0
denominator = 0
for i in range(len(np_array)):
    numerator += (np_array[i][2] - yAvg) * (np_array[i][2] - yAvg)
    denominator += (np_array[i][1] - yAvg) * (np_array[i][1] - yAvg)

# %%
rSq = numerator / denominator
print(rSq)
# Out:
# 1.0000000000000004

# %%
x = 15
y = f(x, m, c)
print(x, y)
plt.scatter(x, y)
for i in range(len(np_array)):
    plt.scatter(np_array[i][0], np_array[i][1])
# Out:
# 15 10.99

# %% [markdown]
# # New Random Data

# %%
data = pd.read_csv('pizza2.csv')
data.head()
# Out:
#     X      Y
# 0  10   5.99
# 1  12   7.59
# 2  14   9.29
# 3  16  11.00
# 4  18  12.99

# %%
xAvg = sum(dominos['X']) / len(dominos)
print(xAvg)
yAvg = sum(dominos['Y']) / len(dominos)
print(yAvg)
xyAvg = sum(dominos['X'] * dominos['Y']) / len(dominos)
print(xyAvg)
xSqAvg = sum(dominos['X'] * dominos['X']) / len(dominos)
print(xSqAvg)
m = ((xAvg * yAvg) - xyAvg) / ((xAvg * xAvg) - xSqAvg)
print(m)
c = yAvg - (m * xAvg)
print(c)
